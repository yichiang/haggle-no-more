# %%
import folium; 
folium.Map(location=(13.7187507, 100.5603644), zoom_start=14)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import os

# %%
m = folium.Map(location=[22.5, -115], zoom_start=4)

video = folium.raster_layers.VideoOverlay(
    video_url='https://www.mapbox.com/bites/00188/patricia_nasa.webm',
    bounds=[[32, -130], [13, -100]],
    opacity=0.65,
    attr='Video from patricia_nasa',
    autoplay=True,
    loop=False,
)

video.add_to(m)

m.save(os.path.join('results', 'VideoOverlayLayer.html'))

m
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-84dda1c19f95> in <module>
#      12 video.add_to(m)
#      13
# ---> 14 m.save(os.path.join('results', 'VideoOverlayLayer.html'))
#      15
#      16 m
#
# /usr/local/lib/python3.7/site-packages/branca/element.py in save(self, outfile, close_file, **kwargs)
#     162         """
#     163         if isinstance(outfile, text_type) or isinstance(outfile, binary_type):
# --> 164             fid = open(outfile, 'wb')
#     165         else:
#     166             fid = outfile
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/VideoOverlayLayer.html'

# %%
bangkok_markets = os.path.join('chatuchat_market.json')
#antarctic_ice_shelf_topo = os.path.join('data', 'antarctic_ice_shelf_topo.json')

m = folium.Map(
    location=[13.752300, 100.539668],
    #tiles='Mapbox Bright',

    zoom_start=14
)

folium.GeoJson(
    bangkok_markets,
    name='geojson'
).add_to(m)

#folium.TopoJson(
#    open(antarctic_ice_shelf_topo),
#    'objects.antarctic_ice_shelf',
#    name='topojson'
#).add_to(m)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
antarctic_ice_edge
# Out:
# 'chatuchat_market.json'
